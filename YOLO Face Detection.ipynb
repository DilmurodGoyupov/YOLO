# %% [markdown]
# # <center> <h1>    🧑  🧑‍💻  🧑

# %% [markdown]
# # <center> Face Detection

# %% [markdown]
# <center>
#
# # ![61ae8d7-6831-7f5c-8b52-01d30ba74ffc_og-ultralytics.jpeg](attachment:043f0339-070c-4cf1-a03a-720ae99a0410.jpeg)

# %% [markdown]
# # <center> Yolov8 ning 5 xili bor. Ular parametrlar soni, mAP(mean Average Precision) o'rtacha aniqlik, va ishlash tezliklari, FLOPs(FLoating-point OPerations per Second) bu ishlash ko'rsatkichi ya'ni soniyada operatsiyalarini bajarish qobiliyati bilan farq qiladi.
#
# <center>
#
# # ![Screenshot 2024-03-29 160308.png](attachment:01c01a42-6521-47b2-9db2-08dd5bad9ea6.png)
#
# ## <center> Biz yolov8n ya'ni nano modelini ishlatamiz

# %% [markdown]
# # <center> Face Detection

# %% [markdown]
# <center> <a href="https://universe.roboflow.com/mohamed-traore-2ekkp/face-detection-mik1i/dataset/24">Datasetni quyidagi havola orqali yuklab olishingiz mumkin.</a>

# %% [markdown]
# # <center> Yuklab olishda Yolov8 ni tanlaymiz.
#
# <center>
#
# # ![Screenshot 2024-04-21 122445.png](attachment:eac17dd6-3802-467c-a3e2-0f53bc5ad596.png)

# %% [markdown]
# # <center> download zip to computerni tanlaymiz so'ngra continue boshish orqali datasetni yuklab olamiz
# <center>
#
# # ![Screenshot 2024-04-21 122531.png](attachment:078bbaf8-d54e-41ea-ac60-c51a51082e32.png)

# %% [markdown]
# ### <center> Datasetimiz quyidagicha annotatsiyalangan rasmlardan iborat
#
# <center>
#
# # ![Screenshot 2024-04-21 122731.png](attachment:6c5b134d-89fb-4da4-ba28-4a2a1850f79e.png)

# %%
from ultralytics import YOLO # Yolo chaqirib olamiz
import cv2
import matplotlib.pyplot as plt

# %%
# YOLOv8n modelini yulab olamiz
model = YOLO('yolov8n.pt')

# %%
# 25 ta epochs train qildiramiz
resluts = model.train(data="/content/gdrive/MyDrive/Datasets/Face Detection_v18/data.yaml", epochs=25, imgsz=640)
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# Bizning o'qitgan modelizning kerakli ma'lumotlari runs/detect/train da saqlangan 
conf_matrix = cv2.imread("runs/detect/train/confusion_matrix.png")
conf_matrix = cv2.cvtColor(conf_matrix, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(15,15))
plt.imshow(conf_matrix)
# confusion matrix ga e'tibor beradigan bo'lsak Faceni 82 marta orqa fon dep qabul qilgan

# %%
resluts_ = cv2.imread("runs/detect/train/results.png")
resluts_ = cv2.cvtColor(resluts_, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(15,15))
plt.imshow(resluts_)
# losslarimizni ko'rishimiz mumkin

# %%
val = model.val(model="runs/detect/train/weights/best.pt", data="D:\\IT\\Python\\YOLO\\yolo\\Datasets\\Face_Detection_v18\\data.yaml")
# test
# model = best.pt train jarayonidagi eng yaxshi modelni yolo saqlab qo'yadi
# Out:
# Ultralytics YOLOv8.1.45  Python-3.9.0 torch-2.2.2+cpu CPU (AMD Ryzen 5 4600H with Radeon Graphics)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning D:\IT\Python\YOLO\yolo\Datasets\Face_Detection_v18\valid\labels.cache... 267 images, 50 backgrounds, 0 co
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 17/17 [01:00
#                    all        267        506      0.921      0.778      0.882      0.548
# Speed: 4.1ms preprocess, 158.8ms inference, 0.0ms loss, 38.4ms postprocess per image
# Results saved to runs\detect\val

# %%
pred = model.predict(model="runs/detect/train/weights/best.pt", source="D:\\IT\\Python\\YOLO\\yolo\\Datasets\\Face_Detection_v18\\test\\images", save=True)
# bir nechta rasmlarni berib test qilib ko'ramiz
# Out:
# image 1/145 D:\IT\Python\YOLO\yolo\Datasets\Face_Detection_v18\test\images\-I1-MS09uaqsLdGTFkgnS0Rcg1mmPyAj95ySg_eckoM_jpeg_jpg.rf.ca3d216ca28be32265e365299a0af4b6.jpg: 640x640 3 faces, 251.9ms
# image 2/145 D:\IT\Python\YOLO\yolo\Datasets\Face_Detection_v18\test\images\0ad90195-cd77-489e-bf85-08c83b80d3e0_jpg.rf.3317b17670bf4318a3b12a9805730774.jpg: 640x640 3 faces, 219.9ms
# image 3/145 D:\IT\Python\YOLO\yolo\Datasets\Face_Detection_v18\test\images\1125506397_15801322206131n_jpg.rf.e15d50e045c169dc1c03cb1c926f90b9.jpg: 640x640 7 faces, 219.8ms
# image 4/145 D:\IT\Python\YOLO\yolo\Datasets\Face_Detection_v18\test\images\1196686205_jpg_14_jpg.rf.70c3ce46b74cee515e2d37cde8fc0202.jpg: 640x640 2 faces, 315.8ms
# image 5/145 D:\IT\Python\YOLO\yolo\Datasets\Face_Detection_v18\test\images\1288788-une-employee-aide-des-voyageurs-en-provenance-de-chine-le-26-janvier-2020-a-l-aeroport-de-roissy_jpg.rf.55458647417fc55d575967c5ef01a74f.jpg: 640x640 6 faces, 187.8ms
# ...

# %%
import glob
s=1
for image_path in glob.glob(f'runs/detect/predict5/*.jpg')[:3]:
    rasm = cv2.imread(image_path)
    rasm = cv2.cvtColor(rasm, cv2.COLOR_BGR2RGB)
    ax = plt.subplot(1,3,s)
    plt.imshow(rasm)
    s+=1

# %%
pred = model.predict(model="runs/detect/train/weights/best.pt", source="D:\\IT\\Python\\YOLO\\yolo\\Photo\\test_face.mp4", save=True)
# video berib test qilib ko'ramiz
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/579) D:\IT\Python\YOLO\yolo\Photo\test_face.mp4: 384x640 4 faces, 266.1ms
# video 1/1 (frame 2/579) D:\IT\Python\YOLO\yolo\Photo\test_face.mp4: 384x640 4 faces, 137.5ms
# video 1/1 (frame 3/579) D:\IT\Python\YOLO\yolo\Photo\test_face.mp4: 384x640 4 faces, 138.8ms
# video 1/1 (frame 4/579) D:\IT\Python\YOLO\yolo\Photo\test_face.mp4: 384x640 4 faces, 136.5ms
# ...

# %%
# Natija
from IPython.display import Video
Video("runs\\detect\\predict5\\test_face.mp4")
# Out:
# <video src="runs\detect\predict5\test_face.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# --------------

# %%
# Endi  yana 25 ta epoch o'qitamiz fa farqni ko'ramiz
resluts = model.train(data="/content/gdrive/MyDrive/Datasets/Face Detection_v18/data.yaml", epochs=25, imgsz=640)
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# Bizning o'qitgan modelizning kerakli ma'lumotlari runs/detect/train2 saqlangan 
conf_matrix = cv2.imread("runs/detect/train2/confusion_matrix.png")
conf_matrix = cv2.cvtColor(conf_matrix, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(15,15))
plt.imshow(conf_matrix)
# Endi esa confusion matrix ga e'tibor beradigan bo'lsak Faceni 70 marta orqa fon dep qabul qilgan
# tepadagidan yaxshiroq

# %%
resluts_ = cv2.imread("runs/detect/train2/results.png")
resluts_ = cv2.cvtColor(resluts_, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(15,15))
plt.imshow(resluts_)
# losslarimizni ko'rishimiz mumkin

# %%
val = model.val(model="runs/detect/train2/weights/best.pt", data="D:\\IT\\Python\\YOLO\\yolo\\Datasets\\Face_Detection_v18\\data.yaml")
# validation
# Out:
# Ultralytics YOLOv8.1.45  Python-3.9.0 torch-2.2.2+cpu CPU (AMD Ryzen 5 4600H with Radeon Graphics)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning D:\IT\Python\YOLO\yolo\Datasets\Face_Detection_v18\valid\labels.cache... 267 images, 50 backgrounds, 0 co
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 17/17 [00:48
#                    all        267        506      0.902      0.785      0.884      0.552
# Speed: 4.6ms preprocess, 160.1ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to runs\detect\val2

# %%
pred = model.predict(model="runs/detect/train2/weights/best.pt", source="D:\\IT\\Python\\YOLO\\yolo\\Datasets\\Face_Detection_v18\\test\\images", save=True)
# bir nechta rasmlarni berib test qilib ko'ramiz
# Out:
# image 1/145 D:\IT\Python\YOLO\yolo\Datasets\Face_Detection_v18\test\images\-I1-MS09uaqsLdGTFkgnS0Rcg1mmPyAj95ySg_eckoM_jpeg_jpg.rf.ca3d216ca28be32265e365299a0af4b6.jpg: 640x640 4 faces, 200.8ms
# image 2/145 D:\IT\Python\YOLO\yolo\Datasets\Face_Detection_v18\test\images\0ad90195-cd77-489e-bf85-08c83b80d3e0_jpg.rf.3317b17670bf4318a3b12a9805730774.jpg: 640x640 4 faces, 204.3ms
# image 3/145 D:\IT\Python\YOLO\yolo\Datasets\Face_Detection_v18\test\images\1125506397_15801322206131n_jpg.rf.e15d50e045c169dc1c03cb1c926f90b9.jpg: 640x640 8 faces, 204.1ms
# image 4/145 D:\IT\Python\YOLO\yolo\Datasets\Face_Detection_v18\test\images\1196686205_jpg_14_jpg.rf.70c3ce46b74cee515e2d37cde8fc0202.jpg: 640x640 3 faces, 204.2ms
# image 5/145 D:\IT\Python\YOLO\yolo\Datasets\Face_Detection_v18\test\images\1288788-une-employee-aide-des-voyageurs-en-provenance-de-chine-le-26-janvier-2020-a-l-aeroport-de-roissy_jpg.rf.55458647417fc55d575967c5ef01a74f.jpg: 640x640 6 faces, 204.1ms
# ...

# %%
import glob
s=1
for image_path in glob.glob(f'runs/detect/predict6/*.jpg')[:3]:
    rasm = cv2.imread(image_path)
    rasm = cv2.cvtColor(rasm, cv2.COLOR_BGR2RGB)
    ax = plt.subplot(1,3,s)
    plt.imshow(rasm)
    s+=1

# %%
pred = model.predict(model="runs/detect/train2/weights/best.pt", source="D:\\IT\\Python\\YOLO\\yolo\\Photo\\test_face.mp4", save=True)
# video berib test qilib ko'ramiz
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/579) D:\IT\Python\YOLO\yolo\Photo\test_face.mp4: 384x640 4 faces, 188.4ms
# video 1/1 (frame 2/579) D:\IT\Python\YOLO\yolo\Photo\test_face.mp4: 384x640 4 faces, 160.2ms
# video 1/1 (frame 3/579) D:\IT\Python\YOLO\yolo\Photo\test_face.mp4: 384x640 4 faces, 141.6ms
# video 1/1 (frame 4/579) D:\IT\Python\YOLO\yolo\Photo\test_face.mp4: 384x640 4 faces, 141.6ms
# ...

# %%
# Natija
from IPython.display import Video
Video("runs\\detect\\predict6\\test_face.mp4")
# Out:
# <video src="runs\detect\predict6\test_face.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
resluts_25 = cv2.imread("runs/detect/train/results.png")
resluts_25 = cv2.cvtColor(resluts_25, cv2.COLOR_BGR2RGB)

resluts_50 = cv2.imread("runs/detect/train2/results.png")
resluts_50 = cv2.cvtColor(resluts_50, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(20,20))

plt.subplot(121)
plt.title("25 ta Epochdan keyin")
plt.imshow(resluts_25)

plt.subplot(122)
plt.title("50 ta Epochdan keyin")
plt.imshow(resluts_50)

# E'tibor beradigan bo'lsangiz 25-epochdan keyin box_loss 1.0 ga tushgan bo'lsa 50-epochdan box_lox 0.8 tushgan ya'ni yaxshilangan

# %% [markdown]
# # <center> Real Time Face Detection

# %%
model = YOLO("runs/detect/train2/weights/best.pt")

# %%
classNames = ["Face"]

# %%
import math
cap = cv2.VideoCapture(0)

# cameramizni olchamini to'g'irlab olamiz
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)

while True:
    _, frame = cap.read() # kadrlarni olamiz
    frame = cv2.flip(frame, 1) # bizda video tasvir(kadrlarimiz) teskari ko'rinishda keladi, shu kod orqali biz uni tog'irlab olamiz
    results = model(frame, stream=True) # frame(kadr) ni modelga beramiz. stream=True orqali bashorat uzluksiz oqim ya'ni kadr ekanini bildiramiz

    # bounding box(chegaraviy ramkalar) larni kordinatalarini olamiz
    for r in results:
        boxes = r.boxes

        for box in boxes:
            # bounding box
            x1, y1, x2, y2 = box.xyxy[0] # modelimizdan boxunding box larning qiymatlarini olamiz
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # ularniing qiymatini intga o'takizb olamiz
            
            # bounding boxni chizmiz
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 3)

            # accuracy(aniqlik)
            accuracy = math.ceil((box.conf[0]*100))/100
            #print(box.conf[0])
            print("Accuracy ---> ",accuracy)

            # qaysi classga tegishliligini olamiz
            cls = int(box.cls[0]) # qaysi classga tegishliligini olamiz son qiymatida
            print("Class nomi --> ", classNames[cls]) # class nomini chiqaramiz

            # class nomini yozamiz
            cv2.putText(frame, classNames[cls] + ": " + str(accuracy), (x1,y1), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 1)

    cv2.imshow('Webcamera', frame) #Kadrlarni ko'rish
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 face, 291.5ms
# Accuracy --->  0.88
# Class nomi -->  Face
# Speed: 5.3ms preprocess, 291.5ms inference, 6833.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 193.2ms
# Accuracy --->  0.89
# Class nomi -->  Face
# Speed: 9.0ms preprocess, 193.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 130.2ms
# Accuracy --->  0.89
# Class nomi -->  Face
# Speed: 3.0ms preprocess, 130.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 139.7ms
# Accuracy --->  0.88
# Class nomi -->  Face
# Speed: 4.0ms preprocess, 139.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 132.4ms
# Accuracy --->  0.89
# Class nomi -->  Face
# Speed: 3.0ms preprocess, 132.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 132.3ms
# Accuracy --->  0.89
# Class nomi -->  Face
# ...

# %%
cap.release()
cv2.destroyAllWindows()

# %%
# Yoki modelimini quyidagicha yoloni o'zida ham ishlatishimiz mumkin
resluts = model.predict(source="0", show=True) #source="0" orqali biz web kamerani ishlatishimizni bildiramiz.
print(resluts)

# %% [markdown]
# # <center> <h1> 👨‍💻   🚀
