# %% [markdown]
# # <center> <h1>    🚖 🚘 🚙 🚐  🧑‍💻  🚐 🚙 🚘🚖

# %% [markdown]
# <center>
#
# # ![61ae8d7-6831-7f5c-8b52-01d30ba74ffc_og-ultralytics.jpeg](attachment:db1feed1-c920-46be-8d5b-7de642a508e3.jpeg)

# %%
# We can connect Colab with google drive
# Do not use this code if you are working on your own computer
from google.colab import drive

drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# install ultralytics
# !pip install ultralytics

# %%
from ultralytics import YOLO # Yolo 
import cv2 # opencv
import matplotlib.pyplot as plt # matplotlib

# %% [markdown]
# # <center> We use the YOLOv8s model
#
# <center>
#
# # ![Screenshot 2024-03-29 160308.png](attachment:5bbb0dd5-c5b7-4417-ad66-bb9f32707430.png)

# %% [markdown]
# # <center> `We segment the car parts.`

# %% [markdown]
# <center> <a href="https://universe.roboflow.com/atheer-algarni-gvico/car-parts-human-in-the-loop/dataset/1">You can download the dataset from the link below.</a>

# %% [markdown]
# # <center> Select Yolov8 when downloading.
#
# <center>
#
# # ![Screenshot 2024-04-01 165932.png](attachment:06071784-501a-481b-bf29-d2252077da9d.png)

# %% [markdown]
# # <center> Select download zip to computer, then click continue to download the dataset
# <center>
#
# # ![Screenshot 2024-04-01 170025.png](attachment:04c4db13-dad2-490b-b7a3-b9dd1b9e0f7e.png)

# %% [markdown]
# ### <center> Our dataset consists of images annotated as follows.
#
# <center>
#
# # ![Screenshot 2024-04-01 170118.png](attachment:af003520-8c93-49ba-8b82-3582dcadb353.png)

# %%
# We download the model for segmentatsya of yolov8s
model = YOLO('yolov8s-seg.pt')
# Out:
# ...
# 100%|██████████| 22.8M/22.8M [00:00<00:00, 148MB/s]

# %%
# train
resluts = model.train(data="/content/gdrive/MyDrive/Datasets/car parts human in the loop.v1i.yolov8/data.yaml", epochs=20, imgsz=640)
# Out:
# Ultralytics YOLOv8.1.40 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# we will teach another 20 epochs
resluts = model.train(data="/content/gdrive/MyDrive/Datasets/car parts human in the loop.v1i.yolov8/data.yaml", epochs=20, imgsz=640)
# Out:
# Ultralytics YOLOv8.1.40 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# we will teach another 10 epochs
resluts = model.train(data="/content/gdrive/MyDrive/Datasets/car parts human in the loop.v1i.yolov8/data.yaml", epochs=10, imgsz=640)
# Out:
# Ultralytics YOLOv8.1.40 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !ls /content/runs/segment/train22/
# list of files stored in our train folder
# Out:
# args.yaml					   labels.jpg	     train_batch2.jpg
# BoxF1_curve.png					   MaskF1_curve.png  val_batch0_labels.jpg
# BoxP_curve.png					   MaskP_curve.png   val_batch0_pred.jpg
# BoxPR_curve.png					   MaskPR_curve.png  val_batch1_labels.jpg
# BoxR_curve.png					   MaskR_curve.png   val_batch1_pred.jpg
# confusion_matrix_normalized.png			   results.csv	     val_batch2_labels.jpg
# confusion_matrix.png				   results.png	     val_batch2_pred.jpg
# events.out.tfevents.1711966593.5c2e80197832.266.2  train_batch0.jpg  weights
# labels_correlogram.jpg				   train_batch1.jpg

# %%
matrix = cv2.imread("/content/runs/segment/train22/confusion_matrix.png")
matrix = cv2.cvtColor(matrix, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,10))
plt.imshow(matrix)
# view confusion matrix

# %%
reults_ = cv2.imread("/content/runs/segment/train22/results.png")
reults_ = cv2.cvtColor(reults_, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,10))
plt.imshow(reults_)
# view losses

# %%
batch_result = cv2.imread("/content/runs/segment/train22/val_batch0_pred.jpg")
batch_result = cv2.cvtColor(batch_result, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,10))
plt.imshow(batch_result)
# we can see the validated images in the train process

# %%
# test
val = model.val(model="/content/runs/detect/train22/weights/best.pt", data="/content/gdrive/MyDrive/Datasets/car parts human in the loop.v1i.yolov8/data.yaml")
# yolo keeps the best model in the train process model = best.pt
# Out:
# Ultralytics YOLOv8.1.40 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s-seg summary (fused): 195 layers, 11787727 parameters, 0 gradients, 42.5 GFLOPs
# val: Scanning /content/gdrive/MyDrive/Datasets/car parts human in the loop.v1i.yolov8/valid/labels.cache... 554 images, 0 backgrounds, 0 corrupt: 100%|██████████| 554/554 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 35/35 [00:31<00:00,  1.12it/s]
#                    all        554       8685      0.888      0.827      0.882       0.69      0.885      0.797      0.851      0.589
#            Back-bumper        554        258      0.932      0.849      0.897      0.743      0.927      0.833      0.884      0.662
#              Back-door        554        415      0.942      0.942      0.975      0.836      0.926      0.913      0.951      0.643
# ...

# %%
# Let's test with a picture
pred = model.predict(model="/content/runs/detect/train22/weights/best.pt", source="/content/gdrive/MyDrive/Datasets/car/", save=True)
# Out:
# image 1/2 /content/gdrive/MyDrive/Datasets/car/bmw.jpg: 448x640 1 Back-windshield, 1 Front-bumper, 2 Headlights, 1 Hood, 2 License-plates, 2 Mirrors, 1 Roof, 1 Windshield, 34.0ms
# image 2/2 /content/gdrive/MyDrive/Datasets/car/car23.jpg: 384x640 1 Back-bumper, 1 Back-door, 1 Back-wheel, 2 Back-windows, 1 Front-door, 2 Front-windows, 1 Quarter-panel, 1 Rocker-panel, 1 Tail-light, 1 Trunk, 28.0ms
# Speed: 2.2ms preprocess, 31.0ms inference, 21.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/segment/train227

# %%
test = cv2.imread("/content/runs/segment/train227/bmw.jpg")
test = cv2.cvtColor(test, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,10))
plt.imshow(test)

# %% [markdown]
# # <center> <h1> 👨‍💻   🚀
